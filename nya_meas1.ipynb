# %%
require 'socket'
require './rp_socket'
tcpipObj = RP.new '192.168.0.5'; puts '# Open connection with your Red Pitaya'
tcpipObj.send 'ACQ:DEC 10'
tcpipObj.send 'ACQ:SOUR1:GAIN HV'
tcpipObj.send 'ACQ:TRIG:LEV 0'
tcpipObj.send 'ACQ:TRIG:DLY 0'
tcpipObj.send 'ACQ:START'
tcpipObj.send 'ACQ:TRIG NOW'
sleep 1
# signal_str = tcpipObj.query 'ACQ:SOUR1:DATA?'
ndata = 300                                                                                              
signal_str = tcpipObj.query "ACQ:SOUR1:DATA:OLD:N? #{ndata}"                                             
puts "signal_str.length = #{signal_str.length}"
puts "signal_str.min = #{signal_str[1..-2].split(',').map{|a|a.to_f}.min}"
puts "signal_str.max = #{signal_str[1..-2].split(',').map{|a|a.to_f}.max}"
data=signal_str[1..-2].split(',').map{|a|a.to_f}
f=File.open('data.txt','w')
data.each_with_index{|y,x|  f.puts "#{x},#{y}"}
f.close
tcpipObj.close; puts '# Close connection with Red Pitaya'
x=[]
0.upto(data.size-1){|a| x.push a}
# plot data
require 'nyaplot'
plot = Nyaplot::Plot.new
line = plot.add(:line, x, data)
plot.show
# Out:
# # Open connection with your Red Pitaya
# signal_str.length = 2817
# signal_str.min = -1.05341
# signal_str.max = 0.902174
# # Close connection with Red Pitaya
# #<Nyaplot::Frame:0x2d1518 @properties={:panes=>[#<Nyaplot::Plot:0x36d800 @properties={:diagrams=>[#<Nyaplot::Diagram:0x2d1ef0 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"693b0e83-7470-4da6-93d6-8f37c37efefe"}, @xrange=[0, 299], @yrange=[-1.05341, 0.902174]>], :options=>{:zoom=>true, :width=>700, :xrange=>[0, 299], :yrange=>[-1.05341, 0.902174]}}>], :data=>{"693b0e83-7470-4da6-93d6-8f37c37efefe"=>#<Nyaplot::DataFrame:0x36c3f0 @name="693b0e83-7470-4da6-93d6-8f37c37efefe", @rows=[{:data0=>0, :data1=>0.0}, {:data0=>1, :data1=>0.758765}, {:data0=>2, :data1=>0.779624}, {:data0=>3, :data1=>0.816128}, {:data0=>4, :data1=>0.839595}, {:data0=>5, :data1=>0.823951}, {:data0=>6, :data1=>0.852633}, {:data0=>7, :data1=>0.878707}, {:data0=>8, :data1=>0.889137}, {:data0=>9, :data1=>0.894352}, {:data0=>10, :data1=>0.891744}, {:data0=>11, :data1=>0.896959}, {:data0=>12, :data1=>0.878707}, {:data0=>13, :data1=>0.891744}, {:data0=>14, :data1=>0.891744}, {:data0=>15, :data1=>0.868277}, {:data0=>16, :data1=>0.863062}, {:data0=>17, :data1=>0.847418}, {:data0=>18, :data1=>0.84481}, {:data0=>19, :data1=>0.839595}, {:data0=>20, :data1=>0.810914}, {:data0=>21, :data1=>0.777017}, {:data0=>22, :data1=>0.784839}, {:data0=>23, :data1=>0.740513}, {:data0=>24, :data1=>0.711831}, {:data0=>25, :data1=>0.693579}, {:data0=>26, :data1=>0.66229}, {:data0=>27, :data1=>0.633608}, {:data0=>28, :data1=>0.584066}, {:data0=>29, :data1=>0.555385}, {:data0=>30, :data1=>0.511058}, {:data0=>31, :data1=>0.469339}, {:data0=>32, :data1=>0.409368}, {:data0=>33, :data1=>0.385901}, {:data0=>34, :data1=>0.352004}, {:data0=>35, :data1=>0.297248}, {:data0=>36, :data1=>0.242492}, {:data0=>37, :data1=>0.190343}, {:data0=>38, :data1=>0.138194}, {:data0=>39, :data1=>0.10169}, {:data0=>40, :data1=>0.0599711}, {:data0=>41, :data1=>-0.00260744}, {:data0=>42, :data1=>-0.0365041}, {:data0=>43, :data1=>-0.0990827}, {:data0=>44, :data1=>-0.153839}, {:data0=>45, :data1=>-0.187736}, {:data0=>46, :data1=>-0.237277}, {:data0=>47, :data1=>-0.284211}, {:data0=>48, :data1=>-0.328537}, {:data0=>49, :data1=>-0.396331}, {:data0=>50, :data1=>-0.443265}, {:data0=>51, :data1=>-0.477161}, {:data0=>52, :data1=>-0.505843}, {:data0=>53, :data1=>-0.563207}, {:data0=>54, :data1=>-0.615356}, {:data0=>55, :data1=>-0.649252}, {:data0=>56, :data1=>-0.688364}, {:data0=>57, :data1=>-0.717046}, {:data0=>58, :data1=>-0.771802}, {:data0=>59, :data1=>-0.800484}, {:data0=>60, :data1=>-0.808306}, {:data0=>61, :data1=>-0.847418}, {:data0=>62, :data1=>-0.891744}, {:data0=>63, :data1=>-0.912604}, {:data0=>64, :data1=>-0.949108}, {:data0=>65, :data1=>-0.951715}, {:data0=>66, :data1=>-0.964752}, {:data0=>67, :data1=>-0.97779}, {:data0=>68, :data1=>-1.01951}, {:data0=>69, :data1=>-1.02994}, {:data0=>70, :data1=>-1.03255}, {:data0=>71, :data1=>-1.03776}, {:data0=>72, :data1=>-1.04037}, {:data0=>73, :data1=>-1.04558}, {:data0=>74, :data1=>-1.03776}, {:data0=>75, :data1=>-1.0508}, {:data0=>76, :data1=>-1.05341}, {:data0=>77, :data1=>-1.05341}, {:data0=>78, :data1=>-1.0508}, {:data0=>79, :data1=>-1.03515}, {:data0=>80, :data1=>-1.03255}, {:data0=>81, :data1=>-0.988219}, {:data0=>82, :data1=>-0.998649}, {:data0=>83, :data1=>-0.969967}, {:data0=>84, :data1=>-0.975182}, {:data0=>85, :data1=>-0.920426}, {:data0=>86, :data1=>-0.907389}, {:data0=>87, :data1=>-0.889137}, {:data0=>88, :data1=>-0.868277}, {:data0=>89, :data1=>-0.826558}, {:data0=>90, :data1=>-0.784839}, {:data0=>91, :data1=>-0.756157}, {:data0=>92, :data1=>-0.698794}, {:data0=>93, :data1=>-0.675327}, {:data0=>94, :data1=>-0.623178}, {:data0=>95, :data1=>-0.573637}, {:data0=>96, :data1=>-0.524095}, {:data0=>97, :data1=>-0.490199}, {:data0=>98, :data1=>-0.453694}, {:data0=>99, :data1=>-0.404153}, {:data0=>100, :data1=>-0.331145}, {:data0=>101, :data1=>-0.299855}, {:data0=>102, :data1=>-0.250314}, {:data0=>103, :data1=>-0.195558}, {:data0=>104, :data1=>-0.151231}, {:data0=>105, :data1=>-0.119942}, {:data0=>106, :data1=>-0.0625785}, {:data0=>107, :data1 ...
